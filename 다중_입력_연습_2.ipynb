# %% [markdown]
# <a href="https://colab.research.google.com/github/leejunho12316/P-Project-Machine-Learning/blob/main/%EB%8B%A4%EC%A4%91_%EC%9E%85%EB%A0%A5_%EC%97%B0%EC%8A%B5_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
#from tensorflow.keras.models import Sequential
#from tensorflow.keras.layers import Dense
#from tensorflow.keras import optimizers

# %% [markdown]
# 1. 데이터
# x = 중간성적, 기말성적, 추가성적
# y = 점수(?)

# %%
x = np.array([[70,85,11],
             [71,89,18],
             [50,80,20],
             [99,20,10],
             [50,10,10]])
y = np.array([73,82,72,57,34])

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(1, input_dim = 3, activation='linear'))

sgd = tf.keras.optimizers.SGD(learning_rate = 0.0001)

model.compile(optimizer=sgd, loss='mse', metrics=['mse'])
model.fit(x,y,epochs=2000)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 322ms/step - loss: 16072.3418 - mse: 16072.3418
# Epoch 2/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 8560.0371 - mse: 8560.0371
# Epoch 3/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 4576.4580 - mse: 4576.4580
# Epoch 4/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 2460.9060 - mse: 2460.9060
# Epoch 5/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 1335.2933 - mse: 1335.2933
# Epoch 6/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 734.9800 - mse: 734.9800
# Epoch 7/2000
# 1/1 [==============================] - 0s 12ms/step - loss: 413.8692 - mse: 413.8692
# Epoch 8/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 241.4621 - mse: 241.4621
# Epoch 9/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 148.4559 - mse: 148.4559
# Epoch 10/2000
# ...

# %%
test = np.array([[70,85,130]])
model.predict(test)
# Out:
# 1/1 [==============================] - 0s 84ms/step
# array([[192.75578]], dtype=float32)
